# %% [markdown]
# # Merging Vax and Symptoms CSV

# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
vax_csv = "../Resources/Data/clean_vaers_vax.csv"
symptoms_csv = "../Resources/Data/grouped_vaers_symptoms.csv"

# %%
vaers_vax = pd.read_csv(vax_csv, index_col=None, header=0, encoding='latin1', low_memory=False)
vaers_vax.head()
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU                             VAX_NAME
# 0    916600  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 1    916601  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 2    916602  COVID19  PFIZER\BIONTECH  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3    916603  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 4    916604  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))

# %%
# reading vaers symptoms as dataframe
vaers_symptoms = pd.read_csv(symptoms_csv, index_col=None, header=0, encoding='latin1', low_memory=False)
vaers_symptoms.head()
# Out:
#    Unnamed: 0  VAERS_ID                 SYMPTOM1                 SYMPTOM2  \
# 0           0    916600                Dysphagia             Epiglottitis
# 1           1    916601                  Anxiety                 Dyspnoea
# 2           2    916602         Chest discomfort                Dysphagia
# 3           3    916603                Dizziness                  Fatigue
# 4           4    916604  Injection site erythema  Injection site pruritus
#
#                   SYMPTOM3               SYMPTOM4 SYMPTOM5
# 0                        0                      0        0
# 1                        0                      0        0
# 2        Pain in extremity      Visual impairment        0
# 3       Mobility decreased                      0        0
# 4  Injection site swelling  Injection site warmth        0

# %%
# using merge function by setting how='inner'
vaxsymp = pd.merge(vaers_vax, vaers_symptoms, 
                   on='VAERS_ID', 
                   how='inner')
vaxsymp.head()
# Out:
#    VAERS_ID VAX_TYPE         VAX_MANU                             VAX_NAME  \
# 0    916600  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 1    916601  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 2    916602  COVID19  PFIZER\BIONTECH  COVID19 (COVID19 (PFIZER-BIONTECH))
# 3    916603  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
# 4    916604  COVID19          MODERNA          COVID19 (COVID19 (MODERNA))
#
#    Unnamed: 0                 SYMPTOM1                 SYMPTOM2  \
# 0           0                Dysphagia             Epiglottitis
# 1           1                  Anxiety                 Dyspnoea
# 2           2         Chest discomfort                Dysphagia
# 3           3                Dizziness                  Fatigue
# 4           4  Injection site erythema  Injection site pruritus
#
#                   SYMPTOM3               SYMPTOM4 SYMPTOM5
# 0                        0                      0        0
# 1                        0                      0        0
# 2        Pain in extremity      Visual impairment        0
# 3       Mobility decreased                      0        0
# 4  Injection site swelling  Injection site warmth        0

# %%
# check column list
list(vaxsymp.columns)
# Out:
# ['VAERS_ID',
#  'VAX_TYPE',
#  'VAX_MANU',
#  'VAX_NAME',
#  'Unnamed: 0',
#  'SYMPTOM1',
#  'SYMPTOM2',
#  'SYMPTOM3',
#  'SYMPTOM4',
#  'SYMPTOM5']

# %%
# after you run this once, it will error if you try it again because well.. its deleted.
# del vaxsymp['Unnamed: 0']

# %%
# check DF
vaxsymp
# Out:
#         VAERS_ID VAX_TYPE         VAX_MANU  \
# 0         916600  COVID19          MODERNA
# 1         916601  COVID19          MODERNA
# 2         916602  COVID19  PFIZER\BIONTECH
# 3         916603  COVID19          MODERNA
# 4         916604  COVID19          MODERNA
# ...          ...      ...              ...
# 389314   1410433  COVID19          MODERNA
# 389315   1410455  COVID19          MODERNA
# 389316   1410468  COVID19          MODERNA
# 389317   1410479  COVID19          MODERNA
# 389318   1410486  COVID19  PFIZER\BIONTECH
#
#                                    VAX_NAME                 SYMPTOM1  \
# 0               COVID19 (COVID19 (MODERNA))                Dysphagia
# 1               COVID19 (COVID19 (MODERNA))                  Anxiety
# 2       COVID19 (COVID19 (PFIZER-BIONTECH))         Chest discomfort
# 3               COVID19 (COVID19 (MODERNA))                Dizziness
# 4               COVID19 (COVID19 (MODERNA))  Injection site erythema
# ...                                     ...                      ...
# 389314          COVID19 (COVID19 (MODERNA))             Bell's palsy
# 389315          COVID19 (COVID19 (MODERNA))               Cold sweat
# 389316          COVID19 (COVID19 (MODERNA))                   Chills
# 389317          COVID19 (COVID19 (MODERNA))         No adverse event
# 389318  COVID19 (COVID19 (PFIZER-BIONTECH))                  Fatigue
#
#                        SYMPTOM2  \
# 0                  Epiglottitis
# 1                      Dyspnoea
# 2                     Dysphagia
# 3                       Fatigue
# 4       Injection site pruritus
# ...                         ...
# 389314                 Erythema
# 389315                   Pallor
# 389316                 Headache
# 389317            Off label use
# 389318                 Headache
#
#                                                  SYMPTOM3  \
# 0                                                       0
# 1                                                       0
# 2                                       Pain in extremity
# 3                                      Mobility decreased
# 4                                 Injection site swelling
# ...                                                   ...
# 389314                                          Urticaria
# 389315                                            Syncope
# 389316                                                  0
# 389317  Product administered to patient of inappropria...
# 389318                                            Myalgia
#
#                      SYMPTOM4 SYMPTOM5
# 0                           0        0
# 1                           0        0
# 2           Visual impairment        0
# 3                           0        0
# 4       Injection site warmth        0
# ...                       ...      ...
# 389314                      0        0
# 389315                      0        0
# 389316                      0        0
# 389317                      0        0
# 389318                      0        0
#
# [389319 rows x 9 columns]

# %% [markdown]
# # Dropping other non-Covid related vaccines

# %%
covid_df = vaxsymp[vaxsymp["VAX_TYPE"] == 'COVID19']
covid_df
# Out:
#         VAERS_ID VAX_TYPE         VAX_MANU  \
# 0         916600  COVID19          MODERNA
# 1         916601  COVID19          MODERNA
# 2         916602  COVID19  PFIZER\BIONTECH
# 3         916603  COVID19          MODERNA
# 4         916604  COVID19          MODERNA
# ...          ...      ...              ...
# 389314   1410433  COVID19          MODERNA
# 389315   1410455  COVID19          MODERNA
# 389316   1410468  COVID19          MODERNA
# 389317   1410479  COVID19          MODERNA
# 389318   1410486  COVID19  PFIZER\BIONTECH
#
#                                    VAX_NAME                 SYMPTOM1  \
# 0               COVID19 (COVID19 (MODERNA))                Dysphagia
# 1               COVID19 (COVID19 (MODERNA))                  Anxiety
# 2       COVID19 (COVID19 (PFIZER-BIONTECH))         Chest discomfort
# 3               COVID19 (COVID19 (MODERNA))                Dizziness
# 4               COVID19 (COVID19 (MODERNA))  Injection site erythema
# ...                                     ...                      ...
# 389314          COVID19 (COVID19 (MODERNA))             Bell's palsy
# 389315          COVID19 (COVID19 (MODERNA))               Cold sweat
# 389316          COVID19 (COVID19 (MODERNA))                   Chills
# 389317          COVID19 (COVID19 (MODERNA))         No adverse event
# 389318  COVID19 (COVID19 (PFIZER-BIONTECH))                  Fatigue
#
#                        SYMPTOM2  \
# 0                  Epiglottitis
# 1                      Dyspnoea
# 2                     Dysphagia
# 3                       Fatigue
# 4       Injection site pruritus
# ...                         ...
# 389314                 Erythema
# 389315                   Pallor
# 389316                 Headache
# 389317            Off label use
# 389318                 Headache
#
#                                                  SYMPTOM3  \
# 0                                                       0
# 1                                                       0
# 2                                       Pain in extremity
# 3                                      Mobility decreased
# 4                                 Injection site swelling
# ...                                                   ...
# 389314                                          Urticaria
# 389315                                            Syncope
# 389316                                                  0
# 389317  Product administered to patient of inappropria...
# 389318                                            Myalgia
#
#                      SYMPTOM4 SYMPTOM5
# 0                           0        0
# 1                           0        0
# 2           Visual impairment        0
# 3                           0        0
# 4       Injection site warmth        0
# ...                       ...      ...
# 389314                      0        0
# 389315                      0        0
# 389316                      0        0
# 389317                      0        0
# 389318                      0        0
#
# [384641 rows x 9 columns]

# %%
# check to make sure only covid vaccines are in the list
covid_list = covid_df['VAX_MANU'].unique()
covid_list
# Out:
# array(['MODERNA', 'PFIZER\\BIONTECH', 'UNKNOWN MANUFACTURER', 'JANSSEN'],
#       dtype=object)

# %%
# save to csv
covid_df.to_csv(r'../Resources/Data/VAERSvaxsymptoms.csv', index=True)
